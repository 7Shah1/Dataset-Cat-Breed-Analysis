# %%
pip install icrawler
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install imagehash Pillow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from icrawler.builtin import BingImageCrawler
import os

# 10 additional cat breeds
cat_breeds = [
    'turkish van',
    'oriental shorthair',
    'savannah cat',
    'russian blue',
    'devon rex',
    'birman cat',
    'american shorthair',
    'manx cat',
    'chartreux',
    'balinese cat'
]

# Create image folders and crawl up to 300 images per breed
for breed in cat_breeds:
    folder_name = breed.replace(" ", "_").lower()
    save_dir = os.path.join('images', folder_name)
    os.makedirs(save_dir, exist_ok=True)

    print(f"Downloading images for: {breed} → {save_dir}")
    crawler = BingImageCrawler(storage={'root_dir': save_dir})
    crawler.crawl(keyword=breed, max_num=300)

print("\n✅ Download complete.")
# Out:
# 2025-05-25 19:20:23,573 - INFO - icrawler.crawler - start crawling...
# 2025-05-25 19:20:23,575 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2025-05-25 19:20:23,582 - INFO - icrawler.crawler - starting 1 parser threads...
# 2025-05-25 19:20:23,584 - INFO - icrawler.crawler - starting 1 downloader threads...
# ...
# 2025-05-25 19:20:23,808 - INFO - parser - no more page urls for thread parser-001 to parse
# 2025-05-25 19:20:23,809 - INFO - parser - thread parser-001 exit
# 2025-05-25 19:20:24,039 - INFO - parser - parsing result page https://www.bing.com/images/async?q=turkish van&first=0
# 2025-05-25 19:20:25,009 - INFO - downloader - image #1	https://animall24.com/wp-content/uploads/2022/05/turkish-van-breed-profile.jpg
# 2025-05-25 19:20:27,098 - INFO - downloader - image #2	https://moderncat.com/wp-content/uploads/2015/12/TurkishVan.jpg
# ...

# %%
import os
from PIL import Image
import imagehash

def remove_duplicates(directory):
    print(f"Checking for duplicates in {directory}...")
    hashes = set()
    removed = 0

    for filename in os.listdir(directory):
        file_path = os.path.join(directory, filename)
        try:
            with Image.open(file_path) as img:
                img_hash = imagehash.average_hash(img)
                if img_hash in hashes:
                    os.remove(file_path)
                    removed += 1
                else:
                    hashes.add(img_hash)
        except Exception as e:
            print(f"Error with {file_path}: {e}")
            continue

    print(f"Removed {removed} duplicate images from {directory}")

# Run for each class directory
root_dir = 'images'
for class_folder in os.listdir(root_dir):
    class_dir = os.path.join(root_dir, class_folder)
    if os.path.isdir(class_dir):
        remove_duplicates(class_dir)
# Out:
# Checking for duplicates in images\abyssinian_cat...
# Removed 0 duplicate images from images\abyssinian_cat
# Checking for duplicates in images\american_shorthair...
# Removed 17 duplicate images from images\american_shorthair
# Checking for duplicates in images\balinese_cat...
# Removed 20 duplicate images from images\balinese_cat
# Checking for duplicates in images\bengal_cat...
# Removed 0 duplicate images from images\bengal_cat
# Checking for duplicates in images\birman_cat...
# Removed 22 duplicate images from images\birman_cat
# Checking for duplicates in images\british_shorthair...
# Removed 0 duplicate images from images\british_shorthair
# Checking for duplicates in images\chartreux...
# Removed 14 duplicate images from images\chartreux
# Checking for duplicates in images\devon_rex...
# Removed 16 duplicate images from images\devon_rex
# Checking for duplicates in images\maine_coon...
# Removed 0 duplicate images from images\maine_coon
# ...
